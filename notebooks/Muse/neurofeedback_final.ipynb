# %%
# conda install PyAudio
# sudo apt install ffmpeg
# conda install -c conda-forge liblsl
# sudo apt install pulseaudio
# sudo apt install libpcap-dev
# sudo setcap 'cap_net_raw,cap_net_admin=eip' $(which hcitool)
# conda install alsa-plugins
# sudo apt install python3-dev

import subprocess
import threading
import pyaudio
import wave
from pynput import keyboard
from pylsl import StreamInlet, resolve_byprop, resolve_stream
import numpy as np
import os
from datetime import datetime
import csv
import time
from pydub import AudioSegment
import io
import shutil
import boto3

# Global flag to control recording state
recording_active = False

def start_muse_lsl_stream():
    """Start the muse2 stream"""
    subprocess.Popen(["muselsl", "stream"], shell=False)

def wait_for_eeg_source(timeout=10):
    """Attempt to find an EEG stream for a given timeout (in seconds)."""
    print("Searching for EEG source...")
    end_time = time.time() + timeout
    while time.time() < end_time:
        try:
            streams = resolve_stream('type', 'EEG')
            if streams:
                print("EEG source found.")
                inlet = StreamInlet(streams[0], max_chunklen=12)
                return inlet
        except Exception as e:
            print(f"Error finding stream: {e}")
        time.sleep(1)
    raise RuntimeError("Failed to find EEG stream within the timeout period.")

def toggle_recording(key):
    """ Toggle recording_active global variable on spacebar press"""
    global recording_active
    if key == keyboard.Key.space: # Check if spacebar is pressed
        if recording_active:
            print("Stopping recordings...")
            recording_active = False
        else:
            print("Starting recordings...")
            recording_active = True

def record_audio(filename):
    """Record audio from the inbuilt microphone and save it as an MP3 file.
    The recording is synchronized with the EEG stream."""

    global recording_active
    FORMAT = pyaudio.paInt16
    CHANNELS = 1
    RATE = 44100
    CHUNK = 1024

    audio = pyaudio.PyAudio()
    stream = audio.open(format=FORMAT, channels=CHANNELS, rate=RATE, input=True, frames_per_buffer=CHUNK)
    
    frames = []
    while recording_active:
        data = stream.read(CHUNK, exception_on_overflow=False)
        frames.append(data)

    # Stop recording
    stream.stop_stream()
    stream.close()
    audio.terminate()

    # Convert the recorded data to an audio segment
    recorded_audio = AudioSegment(
        data=b''.join(frames),
        sample_width=audio.get_sample_size(FORMAT),
        frame_rate=RATE,
        channels=CHANNELS
    )

    # Save the audio segment as an MP3 file
    recorded_audio.export(filename, format="mp3")
    recorded_audio.export()

def collect_eeg_data(filename):

    """Collect raw EEG data from the Muse2 stream and save to a CSV file."""

    global recording_active
    inlet = wait_for_eeg_source()  # Wait for EEG source before proceeding
    
    with open(filename, mode='w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        headers = ['Timestamp'] + [f'Ch{ch}' for ch in range(1, 5)] # Define and write your CSV headers based on our EEG data structure
        csv_writer.writerow(headers)

        while recording_active:
            """ Attempt to pull a chunk of EEG data from the LSL inlet. 
            `eeg_data` will contain the EEG measurements as a 2D list or array,
            where each sublist or row corresponds to a single sample and each column to a channel.
            `timestamps` will contain the corresponding timestamps for each sample.
            The function will wait for up to 1 second (`timeout=1`) to collect the data,
            and will gather a maximum of 12 samples (`max_samples=12`) during this period.
            If no data is available within the timeout period, `eeg_data` and `timestamps` will be empty."""
            eeg_data, timestamps = inlet.pull_chunk(timeout=1, max_samples=12) 
            if timestamps:
                for i, timestamp in enumerate(timestamps):
                    row = [timestamp] + eeg_data[i]
                    csv_writer.writerow(row)

def list_new_files(directory, extensions):
    new_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(extensions):
                new_files.append(os.path.join(root, file))
    return new_files

def upload_new_files_and_move(folder_path, bucket_name, s3_folder, uploaded_subfolder):
    s3_client = boto3.client('s3')
    uploaded_folder_path = os.path.join(folder_path, uploaded_subfolder)

    # Check if the uploaded folder exists, create if not
    if not os.path.exists(uploaded_folder_path):
        os.makedirs(uploaded_folder_path)

    for file in os.listdir(folder_path):
        if file == uploaded_subfolder:
            continue  # Skip the uploaded directory itself

        full_path = os.path.join(folder_path, file)

        # Check if it's a file and not a directory
        if os.path.isfile(full_path):
            uploaded_file_path = os.path.join(uploaded_folder_path, file)

            # Check if the file has not been uploaded before
            if not os.path.exists(uploaded_file_path):
                with open(full_path, 'rb') as data:
                    s3_client.upload_fileobj(data, bucket_name, os.path.join(s3_folder, file))
                    print(f"File {file} uploaded successfully to {os.path.join(s3_folder, file)}")

                    # Move the file to the uploaded directory
                    shutil.move(full_path, uploaded_file_path)
                    print(f"File {file} moved to {uploaded_file_path}")


if __name__ == "__main__":

    recordings_dir = 'Recordings'

    if not os.path.exists(recordings_dir): # Create recordings directory if it doesn't exist
        os.makedirs(recordings_dir)
    
    # Setup file paths for EEG data and audio files, by attaching the current date and time to the filename
    eeg_filename = os.path.join(recordings_dir, f"eeg_data_{datetime.now().strftime('%Y_%m_%d_%H_%M_%S')}.csv")
    audio_filename = os.path.join(recordings_dir, f"audio_recording_{datetime.now().strftime('%Y_%m_%d_%H_%M_%S')}.mp3")

    print("Press spacebar to start/stop the recordings...")

    # Start the Muse LSL stream here before entering the waiting loop.
    start_muse_lsl_stream()

    listener = keyboard.Listener(on_press=toggle_recording) # The listener activate the function toggle_recording when spacebar is pressed
    listener.start()

    while not recording_active:
        # Wait for the first spacebar press to activate recording
        time.sleep(0.5)

    # Start threads for muse stream and audio recording
    eeg_thread = threading.Thread(target=collect_eeg_data, args=(eeg_filename,))
    audio_thread = threading.Thread(target=record_audio, args=(audio_filename,))
    eeg_thread.start()
    audio_thread.start()

    while recording_active:
        # Keep the main thread alive while recording is active
        time.sleep(0.5)
  
    audio_thread.join()
    listener.stop()

    print("Recording and streaming have finished.")

    # Usage
    upload_new_files_and_move("Recordings/", "dsr-jhana", "eeg/", "uploaded/")
# Out:
# Press spacebar to start/stop the recordings...
# Searching for Muses, this may take up to 10 seconds...
# Found device Muse-01EE, MAC Address 4D5E2EB4-EB72-1BE0-19D4-501ED06DF20A
# Connecting to Muse-01EE: 4D5E2EB4-EB72-1BE0-19D4-501ED06DF20A...
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:102   INFO| 	IPv4 addr: 7f000001
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: ::1
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::1%lo0
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'gif0' (status: 0, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'stf0' (status: 0, multicast: 0, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'anpi0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'anpi1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en3' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en4' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en2' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'bridge0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'ap1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'ap1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::b0be:83ff:fe7d:5a7b%ap1
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: 2a02:8109:bf0b:2000:1251:b381:12c0:e5b7
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::18b5:d829:da7b:5e9%en0
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:102   INFO| 	IPv4 addr: c0a8b21a
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.879s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: 2a02:8109:b698:0:c19:703f:f8d0:9cd1
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: 2a02:8109:b698:0:9190:114a:d39c:cb89
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::6827:d8ff:fe9b:84b5%awdl0
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::6827:d8ff:fe9b:84b5%llw0
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::2876:53a6:2e3e:bcfd%utun0
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::a0a1:74db:f2ed:d2a9%utun1
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::3cb2:1905:dccc:a595%utun2
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::ce81:b1c:bd2c:69e%utun3
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.746 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.747 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::3a35:fb5e:8fff:c1de%utun4
# 2024-03-14 11:43:12.747 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.747 (  11.880s) [           44A3B]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:12.747 (  11.880s) [           44A3B]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::d96b:699a:2511:7655%utun5
# 2024-03-14 11:43:12.747 (  11.880s) [           44A3B]         api_config.cpp:270   INFO| Loaded default config
# 2024-03-14 11:43:12.748 (  11.881s) [           44A3B]             common.cpp:65    INFO| git:/branch:/build:Release/compiler:Clang-15.0.7/link:SHARED
# 2024-03-14 11:43:12.748 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff02:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface ::1 (Can't assign requested address)
# 2024-03-14 11:43:12.748 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff02:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface 2a02:8109:bf0b:2000:1251:b381:12c0:e5b7 (Can't assign requested address)
# 2024-03-14 11:43:12.748 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff02:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface 2a02:8109:b698:0:c19:703f:f8d0:9cd1 (Can't assign requested address)
# 2024-03-14 11:43:12.748 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff02:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface 2a02:8109:b698:0:9190:114a:d39c:cb89 (Can't assign requested address)
# 2024-03-14 11:43:12.749 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface 2a02:8109:bf0b:2000:1251:b381:12c0:e5b7 (Address already in use)
# 2024-03-14 11:43:12.749 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface fe80::18b5:d829:da7b:5e9%en0 (Address already in use)
# 2024-03-14 11:43:12.749 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface 192.168.178.26 (Address already in use)
# 2024-03-14 11:43:12.749 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface 2a02:8109:b698:0:c19:703f:f8d0:9cd1 (Address already in use)
# 2024-03-14 11:43:12.749 (  11.882s) [           44A3B]         udp_server.cpp:82    WARN| Could not bind multicast responder for ff05:113d:6fdd:2c17:a643:ffe2:1bd1:3cd2 to interface 2a02:8109:b698:0:9190:114a:d39c:cb89 (Address already in use)
# Connected.
# Streaming EEG...
# Starting recordings...
# Searching for EEG source...
# EEG source found.
# 2024-03-14 11:43:17.478 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.478 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.478 (  16.834s) [           44AD7]      netinterfaces.cpp:102   INFO| 	IPv4 addr: 7f000001
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: ::1
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'lo0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::1%lo0
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'gif0' (status: 0, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'stf0' (status: 0, multicast: 0, broadcast: 0)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'anpi0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'anpi1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en3' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en4' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en2' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'bridge0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'ap1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'ap1' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::b0be:83ff:fe7d:5a7b%ap1
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: 2a02:8109:bf0b:2000:1251:b381:12c0:e5b7
# 2024-03-14 11:43:17.479 (  16.834s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::18b5:d829:da7b:5e9%en0
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:102   INFO| 	IPv4 addr: c0a8b21a
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: 2a02:8109:b698:0:c19:703f:f8d0:9cd1
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'en0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: 2a02:8109:b698:0:9190:114a:d39c:cb89
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.479 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'awdl0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::6827:d8ff:fe9b:84b5%awdl0
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'llw0' (status: 1, multicast: 32768, broadcast: 2)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::6827:d8ff:fe9b:84b5%llw0
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun0' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::2876:53a6:2e3e:bcfd%utun0
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun1' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::a0a1:74db:f2ed:d2a9%utun1
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun2' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::3cb2:1905:dccc:a595%utun2
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun3' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.835s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::ce81:b1c:bd2c:69e%utun3
# 2024-03-14 11:43:17.480 (  16.836s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.836s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun4' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.836s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::3a35:fb5e:8fff:c1de%utun4
# 2024-03-14 11:43:17.480 (  16.836s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.836s) [           44AD7]      netinterfaces.cpp:91    INFO| netif 'utun5' (status: 1, multicast: 32768, broadcast: 0)
# 2024-03-14 11:43:17.480 (  16.836s) [           44AD7]      netinterfaces.cpp:105   INFO| 	IPv6 addr: fe80::d96b:699a:2511:7655%utun5
# 2024-03-14 11:43:17.480 (  16.836s) [           44AD7]         api_config.cpp:270   INFO| Loaded default config
# 2024-03-14 11:43:17.487 (  16.843s) [           44AD7]             common.cpp:65    INFO| git:/branch:/build:Release/compiler:Clang-15.0.7/link:SHARED
# Stopping recordings...
# Recording and streaming have finished.
# File eeg_data_2024_03_14_10_28_32.csv uploaded successfully to eeg/eeg_data_2024_03_14_10_28_32.csv
# File eeg_data_2024_03_14_10_28_32.csv moved to Recordings/uploaded/eeg_data_2024_03_14_10_28_32.csv
# File audio_recording_2024_03_14_11_43_00.mp3 uploaded successfully to eeg/audio_recording_2024_03_14_11_43_00.mp3
# File audio_recording_2024_03_14_11_43_00.mp3 moved to Recordings/uploaded/audio_recording_2024_03_14_11_43_00.mp3
# File audio_recording_2024_03_14_11_06_05.mp3 uploaded successfully to eeg/audio_recording_2024_03_14_11_06_05.mp3
# File audio_recording_2024_03_14_11_06_05.mp3 moved to Recordings/uploaded/audio_recording_2024_03_14_11_06_05.mp3
# File eeg_data_2024_03_14_11_20_23.csv uploaded successfully to eeg/eeg_data_2024_03_14_11_20_23.csv
# File eeg_data_2024_03_14_11_20_23.csv moved to Recordings/uploaded/eeg_data_2024_03_14_11_20_23.csv
# File audio_recording_2024_03_14_10_33_33.mp3 uploaded successfully to eeg/audio_recording_2024_03_14_10_33_33.mp3
# File audio_recording_2024_03_14_10_33_33.mp3 moved to Recordings/uploaded/audio_recording_2024_03_14_10_33_33.mp3
# File eeg_data_2024_03_14_11_18_52.csv uploaded successfully to eeg/eeg_data_2024_03_14_11_18_52.csv
# File eeg_data_2024_03_14_11_18_52.csv moved to Recordings/uploaded/eeg_data_2024_03_14_11_18_52.csv
# File eeg_data_2024_03_14_11_10_25.csv uploaded successfully to eeg/eeg_data_2024_03_14_11_10_25.csv
# File eeg_data_2024_03_14_11_10_25.csv moved to Recordings/uploaded/eeg_data_2024_03_14_11_10_25.csv
# File audio_recording_2024_03_14_11_15_37.mp3 uploaded successfully to eeg/audio_recording_2024_03_14_11_15_37.mp3
# File audio_recording_2024_03_14_11_15_37.mp3 moved to Recordings/uploaded/audio_recording_2024_03_14_11_15_37.mp3
# File eeg_data_2024_03_14_11_05_04.csv uploaded successfully to eeg/eeg_data_2024_03_14_11_05_04.csv
# File eeg_data_2024_03_14_11_05_04.csv moved to Recordings/uploaded/eeg_data_2024_03_14_11_05_04.csv
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[1], line 185
#     182 print("Recording and streaming have finished.")
#     184 # Usage
# --> 185 upload_new_files_and_move("Recordings/", "dsr-jhana", "eeg/", "uploaded/")
#
# Cell In[1], line 137, in upload_new_files_and_move(folder_path, bucket_name, s3_folder, uploaded_subfolder)
#     135 # Check if the file has not been uploaded before
#     136 if not os.path.exists(uploaded_file_path):
# --> 137     with open(full_path, 'rb') as data:
#     138         s3_client.upload_fileobj(data, bucket_name, os.path.join(s3_folder, file))
#     139         print(f"File {file} uploaded successfully to {os.path.join(s3_folder, file)}")
#
# File ~/anaconda3/envs/Muse/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# IsADirectoryError: [Errno 21] Is a directory: 'Recordings/uploaded'
# Disconnected.
