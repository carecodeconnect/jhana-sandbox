# %%
"""
Estimate Relaxation/Concentration from Band Powers

This Notebook shows how to buffer, epoch, and transform EEG data from a single
electrode into values for each of the classic frequencies (e.g. alpha, beta, theta)
Furthermore, it generates a neurofeedback metric based on these band powers.

"""

import numpy as np  # Module that simplifies computations on matrices
import matplotlib.pyplot as plt  # Module used for plotting
from pylsl import StreamInlet, resolve_byprop  # Module to receive EEG data
import utils  # Our own utility functions
import subprocess # To start a shell command
import time  # Module for handling time-related operations

# Handy little enumeration to make code more readable

class Band:
    Delta = 0
    Theta = 1
    Alpha = 2
    Beta = 3

""" EXPERIMENTAL PARAMETERS """
# Modify these to change aspects of the signal processing

# Length of the EEG data buffer (in seconds)
# This buffer will hold last n seconds of data and be used for calculations
BUFFER_LENGTH = 5

# Length of the epochs used to compute the FFT (in seconds)
EPOCH_LENGTH = 1

# Amount of overlap between two consecutive epochs (in seconds)
OVERLAP_LENGTH = 0.8

# Amount to 'shift' the start of each next consecutive epoch
SHIFT_LENGTH = EPOCH_LENGTH - OVERLAP_LENGTH

# Index of the channel(s) (electrodes) to be used
# 0 = left ear, 1 = left forehead, 2 = right forehead, 3 = right ear
INDEX_CHANNEL = [2]

SILENCE = 10 # in seconds. Change this line of code to automatically update with LLM output

ALPHA_RELAXATION_THRESHOLD = 0.5
BETA_CONCENTRATION_THRESHOLD = 0.4
THETA_RELAXATION_THRESHOLD = 0.5

# Initialize metrics storage to calculate the mean over the SILENCE period
alpha_metrics = []
theta_metrics = []
beta_metrics = []

# Time tracking
start_time = time.time()
current_time = start_time

if __name__ == "__main__":

    subprocess.Popen(["muselsl", "stream"], shell=False) # Start the stream in a subprocess

    """ 1. CONNECT TO EEG STREAM """

    # Wait for the EEG stream to be found
    while True:
        print('Looking for an EEG stream...')
        streams = resolve_byprop('type', 'EEG', timeout=2)
        if len(streams) > 0:
            print('EEG stream found!')
            break
        else:
            print('No EEG stream found. Retrying in 2 seconds...')
            time.sleep(2)  # Wait for 2 seconds before retrying

    # Set active EEG stream to inlet and apply time correction
    print("Start acquiring data")
    inlet = StreamInlet(streams[0], max_chunklen=12)
    eeg_time_correction = inlet.time_correction()

    # Get the stream info and description
    info = inlet.info()
    description = info.desc()

    # Get the sampling frequency
    # This is an important value that represents how many EEG data points are
    # collected in a second. This influences our frequency band calculation.
    # for the Muse 2016, this should always be 256
    fs = int(info.nominal_srate())

    """ 2. INITIALIZE BUFFERS """

    # Initialize raw EEG data buffer
    eeg_buffer = np.zeros((int(fs * BUFFER_LENGTH), 1))
    filter_state = None  # for use with the notch filter

    # Compute the number of epochs in "buffer_length"
    n_win_test = int(np.floor((BUFFER_LENGTH - EPOCH_LENGTH) /
                              SHIFT_LENGTH + 1))

    # Initialize the band power buffer (for plotting)
    # bands will be ordered: [delta, theta, alpha, beta]
    band_buffer = np.zeros((n_win_test, 4))

    """ 3. GET DATA """

    # The try/except structure allows to quit the while loop by aborting the
    # script with <Ctrl-C>
    print('Press Ctrl-C in the console to break the while loop.')

    try:
        # The following loop acquires data, computes band powers, 
        #and calculates neurofeedback metrics based on those band powers
        while True:

            """ 3.1 ACQUIRE DATA """
            # Obtain EEG data from the LSL stream
            eeg_data, timestamp = inlet.pull_chunk(
                timeout=1, max_samples=int(SHIFT_LENGTH * fs))

            # Only keep the channel we're interested in
            ch_data = np.array(eeg_data)[:, INDEX_CHANNEL]

            # Update EEG buffer with the new data
            eeg_buffer, filter_state = utils.update_buffer(
                eeg_buffer, ch_data, notch=True,
                filter_state=filter_state)

            """ 3.2 COMPUTE BAND POWERS """
            # Get newest samples from the buffer
            data_epoch = utils.get_last_data(eeg_buffer,
                                             EPOCH_LENGTH * fs)

            # Compute band powers
            band_powers = utils.compute_band_powers(data_epoch, fs)
            band_buffer, _ = utils.update_buffer(band_buffer, band_powers)

            # Compute the average band powers for all epochs in buffer
            # This helps to smooth out noise
            smooth_band_powers = np.mean(band_buffer, axis=0)

            print('Delta: ', band_powers[0, Band.Delta], ' Theta: ', band_powers[0, Band.Theta],
                  ' Alpha: ', band_powers[0, Band.Alpha], ' Beta: ', band_powers[0, Band.Beta])


            """ 3.3 COMPUTE NEUROFEEDBACK METRICS """
            # These metrics could also be used to drive brain-computer interfaces

            # Alpha/Delta Protocol:
            # Simple redout of alpha power, divided by delta waves in order to rule out noise
            alpha_metric = smooth_band_powers[Band.Alpha] / \
                smooth_band_powers[Band.Delta]
            print('Alpha Relaxation: ', alpha_metric)

            # Beta Protocol:
            # Beta waves have been used as a measure of mental activity and concentration
            # This beta over theta ratio is commonly used as neurofeedback for ADHD
            beta_metric = smooth_band_powers[Band.Beta] / \
                 smooth_band_powers[Band.Theta]
            print('Beta Concentration: ', beta_metric)

            # Alpha/Theta Protocol:
            # This is another popular neurofeedback metric for stress reduction
            # Higher theta over alpha is supposedly associated with reduced anxiety
            theta_metric = smooth_band_powers[Band.Theta] / \
                 smooth_band_powers[Band.Alpha]
            print('Theta Relaxation: ', theta_metric)

            """ 3.4 RETURN MENTAL STATE"""
            # Given a SILENCE parameter fed from the LLM, calculates the predominant 
            # mental state during this period and returns 3 mental states: relaxed, focused, none

            # Store metrics
            alpha_metrics.append(alpha_metric)
            theta_metrics.append(theta_metric)
            beta_metrics.append(beta_metric)

            # Update current time
            current_time = time.time()

            # Check if SILENCE period has elapsed
            if current_time - start_time >= SILENCE:
                # Compute mean of the metrics over the SILENCE period
                mean_alpha = np.mean(alpha_metrics)
                mean_theta = np.mean(theta_metrics)
                mean_beta = np.mean(beta_metrics)

                # Determine mental state
                if (mean_alpha + mean_theta) > (ALPHA_RELAXATION_THRESHOLD + THETA_RELAXATION_THRESHOLD):
                    mental_state = "Relaxed"
                elif mean_beta > BETA_CONCENTRATION_THRESHOLD:
                    mental_state = "Focused"
                else:
                    mental_state = "None"

                # Reset metrics storage and start time for the next period
                alpha_metrics = []
                theta_metrics = []
                beta_metrics = []
                start_time = time.time()

                print(f"Mental State: {mental_state}")

    except KeyboardInterrupt:
        print('Closing!')
# Out:
# Looking for an EEG stream...
# EEG stream found!
# Start acquiring data
# Searching for Muses, this may take up to 10 seconds...
# Press Ctrl-C in the console to break the while loop.
# Delta:  0.516262497941596  Theta:  -0.13212317043902633  Alpha:  -0.46664600185241956  Beta:  -0.61461348714604
# Alpha Relaxation:  -0.9038928911416118
# Beta Concentration:  4.651822122522247
# Theta Relaxation:  0.2831336171627831
# Mental State: Relaxed
# Delta:  0.7562742243209183  Theta:  0.29874354398159  Alpha:  -0.097880981498053  Beta:  -0.21878851918052175
# Alpha Relaxation:  -0.44362333398659676
# Beta Concentration:  -5.001801332018181
# Theta Relaxation:  -0.29515041522669166
# Mental State: Relaxed
# Delta:  0.782035995704329  Theta:  0.32754685874517836  Alpha:  -0.06293224062770915  Beta:  -0.09053364037868718
# Alpha Relaxation:  -0.30539645469404486
# Beta Concentration:  -1.8696821366076795
# Theta Relaxation:  -0.7875686792117751
# Mental State: Relaxed
# Delta:  0.527474060038088  Theta:  0.041690684535622885  Alpha:  -0.3036328472229895  Beta:  -0.03722679362838172
# Alpha Relaxation:  -0.360602324920154
# Beta Concentration:  -1.7936889801526608
# Theta Relaxation:  -0.5755154977660505
# Mental State: Relaxed
# Delta:  -0.016461907236092543  Theta:  -0.18294187359417227  Alpha:  -0.30199632827023765  Beta:  -0.027643170345972964
# Alpha Relaxation:  -0.4806266257338368
# Beta Concentration:  -2.8018154165846414
# Theta Relaxation:  -0.2862049820438487
# Mental State: Relaxed
# Delta:  -0.03329523058946398  Theta:  -0.1550765454807251  Alpha:  -0.18659138340897005  Beta:  0.007515785217055613
# Alpha Relaxation:  -0.5606308853278787
# Beta Concentration:  -4.960029906212947
# Theta Relaxation:  -0.13935501521834193
# Mental State: Relaxed
# Delta:  -0.20840541591584202  Theta:  -0.024481689716936796  Alpha:  -0.13115123931290992  Beta:  -0.0745673588646456
# Alpha Relaxation:  -0.6673443564877961
# Beta Concentration:  -6.090623758551165
# Theta Relaxation:  -0.11178381496802703
# Mental State: Relaxed
# Delta:  -0.3975643397509818  Theta:  0.14675329894818415  Alpha:  -0.03367352682774498  Beta:  -0.18057948743740587
# Alpha Relaxation:  -0.8225552577016497
# Beta Concentration:  -3.862523495140551
# Theta Relaxation:  -0.20202599429423634
# Mental State: Relaxed
# Delta:  -0.5055793645460178  Theta:  0.1287358903663752  Alpha:  -0.03285943585821094  Beta:  -0.11444396397398017
# Alpha Relaxation:  -1.1383950567675392
# Beta Concentration:  -3.0096684253787336
# Theta Relaxation:  -0.27751761603594866
# Mental State: Relaxed
# Delta:  -0.1441060619719779  Theta:  0.14346783125823184  Alpha:  -0.07635918330527743  Beta:  -0.12845338867581266
# Alpha Relaxation:  -1.326709582040551
# Beta Concentration:  -2.497546833159932
# Theta Relaxation:  -0.34971171188454353
# Mental State: Relaxed
# Delta:  0.29127708519824264  Theta:  0.13054556241262827  Alpha:  -0.017730245123649704  Beta:  -0.1079396405411572
# Alpha Relaxation:  -1.091549724688597
# Beta Concentration:  -2.195823266402115
# Theta Relaxation:  -0.4223663848492899
# Mental State: Relaxed
# Delta:  0.6136261912279629  Theta:  0.06466182437797653  Alpha:  -0.05861757028909005  Beta:  -0.04462515426459321
# Alpha Relaxation:  -0.8113868285057415
# Beta Concentration:  -2.072194012205456
# Theta Relaxation:  -0.44490996276006345
# Mental State: Relaxed
# Delta:  0.6838224468989452  Theta:  0.18649537653831866  Alpha:  -0.009879000179267338  Beta:  -0.02957354035965988
# Alpha Relaxation:  -0.6211958955040455
# Beta Concentration:  -1.705792968566498
# Theta Relaxation:  -0.5472162705755738
# Mental State: Relaxed
# Delta:  0.6698629489671867  Theta:  0.18217855519013493  Alpha:  0.04826225867230096  Beta:  -0.08509638812403782
# Alpha Relaxation:  -0.48983831042192155
# Beta Concentration:  -1.5106163016105087
# Theta Relaxation:  -0.6676701176326639
# Mental State: Relaxed
# Delta:  0.5064958829332545  Theta:  0.2043257215932052  Alpha:  0.21531955991227203  Beta:  -0.11608288714953065
# Alpha Relaxation:  -0.37517901670849324
# Beta Concentration:  -1.3690714406600881
# Theta Relaxation:  -0.8972239723486661
# Mental State: Relaxed
# Delta:  0.5084093143942288  Theta:  0.13290346649641854  Alpha:  0.08893253260716234  Beta:  -0.10785207626050441
# Alpha Relaxation:  -0.3137132691229384
# Beta Concentration:  -1.319452445764774
# Theta Relaxation:  -1.0462295469734884
# Mental State: Relaxed
# Delta:  0.6325627595443692  Theta:  0.1164673094624056  Alpha:  -0.10518592677214583  Beta:  -0.10044403200498059
# Alpha Relaxation:  -0.29571925734766374
# Beta Concentration:  -1.2863887228557436
# Theta Relaxation:  -1.0504175899436594
# Mental State: Relaxed
# Delta:  0.6861708445605645  Theta:  0.5903198667115866  Alpha:  0.3913155581418415  Beta:  -0.07916735535605614
# Alpha Relaxation:  -0.1944680271053417
# Beta Concentration:  -0.9772306481065762
# Theta Relaxation:  -1.927802455296412
# Mental State: Relaxed
# Delta:  0.7916739630686934  Theta:  0.792511978876445  Alpha:  0.5446597519095653  Beta:  0.004681317138195523
# Alpha Relaxation:  -0.08957931594849904
# Beta Concentration:  -0.7168831572424029
# Theta Relaxation:  -5.0159110088210985
# Mental State: Relaxed
# Delta:  0.6964340724745155  Theta:  0.68246860980203  Alpha:  0.372148096290245  Beta:  0.013497021552477145
# Alpha Relaxation:  -0.03051502915116867
# Beta Concentration:  -0.5800883659000831
# Theta Relaxation:  -16.37070528511294
# Mental State: Relaxed
# Delta:  0.6344169828473434  Theta:  0.2495248917164737  Alpha:  -0.08225513905856892  Beta:  -0.07160681580402098
# Alpha Relaxation:  -0.038385488525197735
# Beta Concentration:  -0.5614527158899849
# Theta Relaxation:  -12.79437936997589
# Mental State: Relaxed
# Delta:  0.2951215255385672  Theta:  0.05289607968947801  Alpha:  0.043462280045022506  Beta:  -0.0760555236934264
# Alpha Relaxation:  0.02617098485775341
# Beta Concentration:  -0.4051318890065253
# Theta Relaxation:  20.20967002322264
# Mental State: Relaxed
# Delta:  0.11194836510624073  Theta:  0.044252749891283485  Alpha:  -0.0041751039181907494  Beta:  -0.0003198782352493147
# Alpha Relaxation:  0.04168736983629073
# Beta Concentration:  -0.3752073935528229
# Theta Relaxation:  12.977968055900874
# Mental State: Relaxed
# Delta:  0.20673383177933818  Theta:  -0.06926046705825788  Alpha:  -0.20935588931503077  Beta:  -0.04624041683228237
# Alpha Relaxation:  0.02299587913092992
# Beta Concentration:  -0.40544988596656184
# Theta Relaxation:  22.958729266862623
# Mental State: Relaxed
# Delta:  0.054069673326384744  Theta:  -0.08521983801359112  Alpha:  -0.23089708339318096  Beta:  -0.14610216610383328
# Alpha Relaxation:  0.03675582239324829
# Beta Concentration:  -0.4535753108530883
# Theta Relaxation:  14.914644383111106
# Mental State: Relaxed
# Delta:  0.03562899005145035  Theta:  -0.1417047091830784  Alpha:  -0.18099762911134973  Beta:  -0.17452452709567629
# Alpha Relaxation:  0.05618446328832963
# Beta Concentration:  -0.491578897836799
# Theta Relaxation:  9.793969548197492
# Mental State: Relaxed
# Delta:  0.24097341999022373  Theta:  -0.08769657226467212  Alpha:  -0.1869518124768311  Beta:  -0.07469707890575708
# Alpha Relaxation:  0.05372176539880686
# Beta Concentration:  -0.5058487267640033
# Theta Relaxation:  10.00009653964739
# Mental State: Relaxed
# Delta:  0.30852264517622513  Theta:  -0.03231695294059437  Alpha:  -0.3826054057335709  Beta:  -0.10306453441197738
# Alpha Relaxation:  0.013374332848376283
# Beta Concentration:  -0.5153060977448606
# Theta Relaxation:  37.08317336016691
# Mental State: Relaxed
# Delta:  0.4596143863773083  Theta:  -0.06947788460679613  Alpha:  -0.40953753196454507  Beta:  -0.11191746293201306
# Alpha Relaxation:  -0.036425633666576765
# Beta Concentration:  -0.5286027919625194
# Theta Relaxation:  -11.3519263933631
# Mental State: Relaxed
# Delta:  0.48952480100889983  Theta:  0.4989303106497354  Alpha:  0.30360213970994054  Beta:  -0.07815247354509015
# Alpha Relaxation:  0.006059040805361188
# Beta Concentration:  -0.4639180207265696
# Theta Relaxation:  67.46866477516407
# Mental State: Relaxed
# Delta:  0.8752177471301037  Theta:  0.9213972484755083  Alpha:  0.6593399047567926  Beta:  -0.026937568319392025
# Alpha Relaxation:  0.08056015666598869
# Beta Concentration:  -0.35796252729192446
# Theta Relaxation:  5.532334931645096
# Mental State: Relaxed
# Delta:  0.8812582651165427  Theta:  0.9698136895713951  Alpha:  0.682673435868656  Beta:  -0.06086849699521152
# Alpha Relaxation:  0.1434448710130799
# Beta Concentration:  -0.29118062990237115
# Theta Relaxation:  3.4940039009861015
# Mental State: Relaxed
# Delta:  0.7153815252606526  Theta:  0.6784572002035001  Alpha:  0.39941753011459713  Beta:  -0.06065396248266101
# Alpha Relaxation:  0.18574221949297942
# Beta Concentration:  -0.2632127669399732
# Theta Relaxation:  2.987361453306949
# Mental State: Relaxed
# Delta:  0.14142802733169355  Theta:  0.012403054587378016  Alpha:  0.04592083231944214  Beta:  -0.046551209133039444
# Alpha Relaxation:  0.20148895425208407
# Beta Concentration:  -0.27434143089752666
# Theta Relaxation:  2.817231209838796
# Mental State: Relaxed
# Delta:  -0.05414754413009688  Theta:  -0.028045568630311626  Alpha:  -0.1553190064064398  Beta:  0.014910374595403461
# Alpha Relaxation:  0.19522895676696872
# Beta Concentration:  -0.26654942575490426
# Theta Relaxation:  3.019125697294291
# Mental State: Relaxed
# Delta:  0.10429082828236193  Theta:  0.011887570911724004  Alpha:  -0.21789254246758208  Beta:  0.08103356506839669
# Alpha Relaxation:  0.15499292762872885
# Beta Concentration:  -0.23872348571227578
# Theta Relaxation:  3.8355528828672933
# Mental State: Relaxed
# Delta:  0.07273949811073348  Theta:  -0.00441766045067304  Alpha:  -0.004959939956367561  Beta:  0.011303458918835817
# Alpha Relaxation:  0.1518463760485598
# Beta Concentration:  -0.2217980446186792
# Theta Relaxation:  4.0106607698669166
# Mental State: Relaxed
# Delta:  0.1883189458803079  Theta:  0.05032881395141393  Alpha:  -0.009442114547023607  Beta:  -0.12448190360931441
# Alpha Relaxation:  0.1724127311642189
# Beta Concentration:  -0.22948255083730112
# Theta Relaxation:  3.6816512765211487
# Mental State: Relaxed
# Delta:  0.16788056880380936  Theta:  0.17787711635702258  Alpha:  -0.246954600158781  Beta:  -0.10498559718353127
# Alpha Relaxation:  0.09840598210877095
# Beta Concentration:  -0.2555315939068511
# Theta Relaxation:  6.336121785103476
# Mental State: Relaxed
# Delta:  0.24711932455341093  Theta:  0.1458615003124781  Alpha:  -0.23036146499251392  Beta:  -0.11524169816527895
# Alpha Relaxation:  -0.006568381640529682
# Beta Concentration:  -0.32721725725208
# Theta Relaxation:  -88.12288763499149
# Mental State: Relaxed
# Delta:  0.2513318928397004  Theta:  0.16327311625992197  Alpha:  -0.044488139272947425  Beta:  -0.10068378754221499
# Alpha Relaxation:  -0.071845407079891
# Beta Concentration:  -0.40934791432395684
# Theta Relaxation:  -7.490112310723433
# Mental State: Relaxed
# Delta:  0.160686220320898  Theta:  0.2753517921605233  Alpha:  0.11192287162843678  Beta:  -0.10416009038082742
# Alpha Relaxation:  -0.044947147832800606
# Beta Concentration:  -0.4156559973482473
# Theta Relaxation:  -13.02167453356695
# Mental State: Relaxed
# Delta:  0.16346608512732075  Theta:  0.21412036992541197  Alpha:  0.015187022758655445  Beta:  -0.07710402913263066
# Alpha Relaxation:  -0.05082019270700176
# Beta Concentration:  -0.3975625559956797
# Theta Relaxation:  -12.322165488608496
# Mental State: Relaxed
# Delta:  0.307954316415477  Theta:  0.3167004497568606  Alpha:  0.024936552854030635  Beta:  -0.06760392148388628
# Alpha Relaxation:  -0.04432754406552241
# Beta Concentration:  -0.3870908329175066
# Theta Relaxation:  -14.688185740106414
# Mental State: Relaxed
# Delta:  0.6401604758459433  Theta:  0.4396812616970081  Alpha:  0.18475489650026516  Beta:  0.002268220176884786
# Alpha Relaxation:  0.019739516912164138
# Beta Concentration:  -0.3316347713539193
# Theta Relaxation:  34.764638847315275
# Mental State: Relaxed
# Delta:  0.6125979159628757  Theta:  0.3151730122100947  Alpha:  0.1701497692273584  Beta:  0.018189775408834766
# Alpha Relaxation:  0.07537784065791725
# Beta Concentration:  -0.27009771201222377
# Theta Relaxation:  9.136345485186922
# Mental State: Relaxed
# Delta:  0.614705572705449  Theta:  0.266680577313925  Alpha:  0.1251979698599723  Beta:  -0.029409324948696202
# Alpha Relaxation:  0.10997333341598939
# Beta Concentration:  -0.22131620131957586
# Theta Relaxation:  6.2737154040881205
# Mental State: Relaxed
# Delta:  0.5314266388033214  Theta:  0.5750737615475492  Alpha:  0.16785357686579422  Beta:  -0.07524469343520912
# Alpha Relaxation:  0.15094854459849394
# Beta Concentration:  -0.1965424561626492
# Theta Relaxation:  4.959453356651559
# Mental State: Relaxed
# Delta:  0.9891355177602768  Theta:  0.9392198168453532  Alpha:  0.4130097113889074  Beta:  -0.07292606253066261
# Alpha Relaxation:  0.2318913282442978
# Beta Concentration:  -0.1643623430409288
# Theta Relaxation:  3.4610840871137345
# Mental State: Relaxed
# Delta:  1.027758980799425  Theta:  0.9757615010087467  Alpha:  0.4615394792590195  Beta:  -0.0006240335629467414
# Alpha Relaxation:  0.3128849877714434
# Beta Concentration:  -0.12859828656862507
# Theta Relaxation:  2.7714584608466364
# Mental State: Relaxed
# Delta:  0.8182389594552422  Theta:  0.6613747639250172  Alpha:  0.24623148831772163  Beta:  0.024118808789241785
# Alpha Relaxation:  0.2959429101603895
# Beta Concentration:  -0.1133517197908753
# Theta Relaxation:  2.886312804324034
# Mental State: Relaxed
# No Muses found.
# Delta:  1.7015026377373588  Theta:  1.1481603782901126  Alpha:  0.3153815573683339  Beta:  0.1635450173224481
# Alpha Relaxation:  0.23871466220189
# Beta Concentration:  -0.08731999970808783
# Theta Relaxation:  3.383116999118166
# Mental State: Relaxed
# Delta:  1.9788957032610872  Theta:  1.630649125842254  Alpha:  0.675628462691452  Beta:  0.43843926081042306
# Alpha Relaxation:  0.2150726142736124
# Beta Concentration:  -0.025192127580775752
# Theta Relaxation:  3.662834902852791
# Mental State: Relaxed
# Delta:  2.121986615535469  Theta:  1.7200658067497583  Alpha:  0.8576798095306524  Beta:  0.4791752366016506
# Alpha Relaxation:  0.22725172069083327
# Beta Concentration:  0.03137420821813856
# Theta Relaxation:  3.44365538350753
# Mental State: Relaxed
# Delta:  1.9193925467452082  Theta:  1.493765406550326  Alpha:  0.723670874547545  Beta:  0.2675567951547453
# Alpha Relaxation:  0.24604308668482203
# Beta Concentration:  0.05466971535497398
# Theta Relaxation:  3.2057534976707758
# Mental State: Relaxed
# Delta:  1.715433904272329  Theta:  0.8315816319463668  Alpha:  0.1589369186023647  Beta:  0.019954345282676526
# Alpha Relaxation:  0.23862728105113823
# Beta Concentration:  0.05127232098031249
# Theta Relaxation:  3.167836487249194
# Mental State: Relaxed
# Delta:  0.5166959791333683  Theta:  0.30873855750516316  Alpha:  0.04344625416641031  Beta:  -0.1002961126578176
# Alpha Relaxation:  0.24835580019304496
# Beta Concentration:  0.03572866033756777
# Theta Relaxation:  3.040164784475243
# Mental State: Relaxed
# Delta:  0.5091621806810248  Theta:  0.22693675046175865  Alpha:  -0.022404599391017944  Beta:  -0.11370549081837783
# Alpha Relaxation:  0.2410330665337554
# Beta Concentration:  0.025378315025533973
# Theta Relaxation:  3.1088266733864964
# Mental State: Relaxed
# Delta:  0.5648051911030832  Theta:  0.6039779302665701  Alpha:  -0.07737021330640445  Beta:  -0.11897459413828386
# Alpha Relaxation:  0.23199715048645717
# Beta Concentration:  0.024742175297294663
# Theta Relaxation:  3.2965624432970304
# Mental State: Relaxed
# Delta:  0.8419032066674464  Theta:  0.8163263269608876  Alpha:  0.1469429914634186  Beta:  -0.13309680993852036
# Alpha Relaxation:  0.24502345149310437
# Beta Concentration:  0.02162116618506112
# Theta Relaxation:  3.1488270854853493
# Mental State: Relaxed
# Delta:  0.8611682732400351  Theta:  0.7187215926743957  Alpha:  0.14426453654355936  Beta:  -0.0722876263158698
# Alpha Relaxation:  0.256916742377784
# Beta Concentration:  0.023708965612218615
# Theta Relaxation:  3.023524877374598
# Mental State: Relaxed
# Delta:  0.6204283291714242  Theta:  0.2351248027264229  Alpha:  0.02011098529969066  Beta:  -0.00577211227518632
# Alpha Relaxation:  0.25534380514797433
# Beta Concentration:  0.030043973443544095
# Theta Relaxation:  2.9983641703368233
# Mental State: Relaxed
# Delta:  0.45322092499828653  Theta:  0.08518979839041642  Alpha:  -0.21880686724025816  Beta:  0.03086816733565898
# Alpha Relaxation:  0.23456339339970425
# Beta Concentration:  0.03973489478779685
# Theta Relaxation:  3.173501069939707
# Mental State: Relaxed
# Delta:  0.2320841774380718  Theta:  0.2159153496369496  Alpha:  -0.5474034106470099  Beta:  -0.005437277484446538
# Alpha Relaxation:  0.20500642761707144
# Beta Concentration:  0.04466407361463832
# Theta Relaxation:  3.6187644746933696
# Mental State: Relaxed
# Delta:  0.21625340788999145  Theta:  0.04152003458520141  Alpha:  -0.6699784188321554  Beta:  -0.14498575636645114
# Alpha Relaxation:  0.1703106210224222
# Beta Concentration:  0.040096157173026434
# Theta Relaxation:  4.293565323848901
# Mental State: Relaxed
# Delta:  0.030447747977152877  Theta:  -0.2433562960557688  Alpha:  -0.39224516036023727  Beta:  -0.16433030219949765
# Alpha Relaxation:  0.14524554832316172
# Beta Concentration:  0.02983482901067502
# Theta Relaxation:  4.9479990917779615
# Mental State: Relaxed
# Delta:  -0.1679772141564026  Theta:  -0.23207998093299773  Alpha:  -0.21005189200766425  Beta:  -0.056060874368264145
# Alpha Relaxation:  0.1305010340533261
# Beta Concentration:  0.025385800386547273
# Theta Relaxation:  5.5128556490472835
# Mental State: Relaxed
# Delta:  -0.22875635768983268  Theta:  -0.1184492316436956  Alpha:  -0.13806824180270702  Beta:  -0.06522392616964491
# Alpha Relaxation:  0.12162189903532787
# Beta Concentration:  0.02332490725301124
# Theta Relaxation:  6.020973811953174
# Mental State: Relaxed
# Delta:  -0.14218771655318693  Theta:  -0.039255648053833386  Alpha:  -0.03337332758543876  Beta:  -0.12037608748124377
# Alpha Relaxation:  0.11442626719032808
# Beta Concentration:  0.02076230296968196
# Theta Relaxation:  6.335790966754328
# Mental State: Relaxed
# Delta:  -0.07126459167756209  Theta:  0.04558456819134206  Alpha:  -0.08961989320227304  Beta:  -0.07609004109108189
# Alpha Relaxation:  0.08985720737258153
# Beta Concentration:  0.02214551320072062
# Theta Relaxation:  7.978603617210085
# Mental State: Relaxed
# Delta:  0.07679875963650078  Theta:  0.0382246485298465  Alpha:  -0.1467268128024552  Beta:  -0.09665529216745912
# Alpha Relaxation:  0.05396983007071946
# Beta Concentration:  0.014758024774966563
# Theta Relaxation:  12.958703432973676
# Mental State: Relaxed
# Delta:  0.34849989020894906  Theta:  0.37139505983323506  Alpha:  -0.05400857561664474  Beta:  -0.0393177909760347
# Alpha Relaxation:  0.034472121019380096
# Beta Concentration:  0.008781800290559081
# Theta Relaxation:  20.367562211029416
# Mental State: Relaxed
# Delta:  0.47709294669167057  Theta:  0.4440420073806848  Alpha:  -0.12687891375579483  Beta:  0.04316117134602079
# Alpha Relaxation:  0.0033978733259218507
# Beta Concentration:  -0.0036385543192908004
# Theta Relaxation:  210.18909619262197
# Mental State: Relaxed
# Delta:  0.3105736528175249  Theta:  0.21331844947254627  Alpha:  -0.153117895480918  Beta:  -0.052490741797796
# Alpha Relaxation:  -0.07005341199429287
# Beta Concentration:  -0.0674251936977703
# Theta Relaxation:  -9.907349322267363
# Mental State: Relaxed
# Delta:  0.18188166884391793  Theta:  -0.1338203357710977  Alpha:  -0.17307721397046305  Beta:  -0.17006046227123559
# Alpha Relaxation:  -0.19596655623204204
# Beta Concentration:  -0.1981329198641618
# Theta Relaxation:  -3.2622180747540734
# Mental State: Relaxed
# Delta:  -0.043857975786603234  Theta:  0.10181920879520588  Alpha:  -0.2719452396573758  Beta:  -0.17344409525079477
# Alpha Relaxation:  -0.3849929518294134
# Beta Concentration:  -0.35631417054097086
# Theta Relaxation:  -1.6118288174610003
# Mental State: Relaxed
# Delta:  0.01395525595303302  Theta:  0.15071744488042435  Alpha:  -0.13387408877267973  Beta:  -0.12050778488533402
# Alpha Relaxation:  -0.5542271107481741
# Beta Concentration:  -0.45579596034147263
# Theta Relaxation:  -1.2404511332782868
# Mental State: Relaxed
# Delta:  0.007299743927771738  Theta:  -0.06945211728301964  Alpha:  -0.09205719351165993  Beta:  -0.10790052919858382
# Alpha Relaxation:  -0.6362897772029785
# Beta Concentration:  -0.5076281742369297
# Theta Relaxation:  -1.0718312425884688
# Mental State: Relaxed
# Delta:  -0.18821495981209183  Theta:  -0.2192573697429356  Alpha:  -0.2229189590732951  Beta:  -0.14719991671666444
# Alpha Relaxation:  -0.7829046323312644
# Beta Concentration:  -0.5935427192578218
# Theta Relaxation:  -0.8796590013189739
# Mental State: Relaxed
# Delta:  -0.2522626120356362  Theta:  -0.1152584488627577  Alpha:  -0.15574259848489255  Beta:  -0.22666531263270612
# Alpha Relaxation:  -0.9836430102239399
# Beta Concentration:  -0.8252701653597606
# Theta Relaxation:  -0.6556543725264851
# Mental State: Relaxed
# Delta:  -0.042099748935752385  Theta:  0.05215841206979387  Alpha:  -0.24197342311712405  Beta:  -0.24352161159939617
# Alpha Relaxation:  -1.4509362431089239
# Beta Concentration:  -1.3056103566022605
# Theta Relaxation:  -0.39483170031091425
# Mental State: Relaxed
# Delta:  0.40347714560782133  Theta:  0.2990052768828492  Alpha:  0.03475760237736267  Beta:  -0.18265987676008674
# Alpha Relaxation:  -1.7969996696510537
# Beta Concentration:  -1.8918151835673256
# Theta Relaxation:  -0.2795832118815134
# Mental State: Relaxed
# Delta:  0.8590554423051141  Theta:  0.8292487341839863  Alpha:  0.4919726876752485  Beta:  -0.012894852429339628
# Alpha Relaxation:  -1.4329465512589847
# Beta Concentration:  -1.2414286743167595
# Theta Relaxation:  -0.48438442847334856
# Mental State: Relaxed
# Delta:  0.9855356837624941  Theta:  1.004129317627987  Alpha:  0.6449865498225726  Beta:  0.09873979587718436
# Alpha Relaxation:  -0.8918982753880628
# Beta Concentration:  -0.782930516853495
# Theta Relaxation:  -0.9831445245285604
# Mental State: Relaxed
# Delta:  0.949601600295993  Theta:  0.8478744251790327  Alpha:  0.5037555035603962  Beta:  0.0450169017031103
# Alpha Relaxation:  -0.4377686346299951
# Beta Concentration:  -0.6160957004212171
# Theta Relaxation:  -2.0047461776882494
# Mental State: Relaxed
# Delta:  0.6572432127202714  Theta:  0.2871269676904074  Alpha:  0.08239269749596363  Beta:  -0.11337125159253714
# Alpha Relaxation:  -0.21076777415225662
# Beta Concentration:  -0.5640334599023875
# Theta Relaxation:  -4.002799611539473
# Mental State: Relaxed
# Delta:  0.5142378380304781  Theta:  0.1522864525446133  Alpha:  -0.12322334855828938  Beta:  -0.10861067690658527
# Alpha Relaxation:  -0.13096167226208139
# Beta Concentration:  -0.49269811915958
# Theta Relaxation:  -6.421493940763019
# Mental State: Relaxed
# Delta:  0.39269184832932247  Theta:  0.1268655142776294  Alpha:  -0.13817675372988303  Beta:  -0.1434849286789073
# Alpha Relaxation:  -0.1030690041457143
# Beta Concentration:  -0.47174653511859543
# Theta Relaxation:  -7.94964557412833
# Mental State: Relaxed
# Delta:  0.1684264404530419  Theta:  0.20333591150558325  Alpha:  0.029701269707079075  Beta:  -0.16143499517722515
# Alpha Relaxation:  -0.06584304137321938
# Beta Concentration:  -0.45963566676038276
# Theta Relaxation:  -12.434279451617975
# Mental State: Relaxed
# Delta:  0.1853019657815225  Theta:  0.3364159935005493  Alpha:  0.1293381302520443  Beta:  -0.11637282931541111
# Alpha Relaxation:  -0.03478891151639539
# Beta Concentration:  -0.42405695588557524
# Theta Relaxation:  -24.054665092438338
# Mental State: Relaxed
# Delta:  -0.03378077941922105  Theta:  0.14951658484428515  Alpha:  0.00677339605472068  Beta:  -0.13607347222425298
# Alpha Relaxation:  -0.018428195870626024
# Beta Concentration:  -0.4271952798903932
# Theta Relaxation:  -46.07002593534458
# Mental State: Relaxed
# Delta:  -0.2224008506491684  Theta:  -0.1299273805303329  Alpha:  -0.08737324883751589  Beta:  -0.17162202411892158
# Alpha Relaxation:  -0.008936409610028008
# Beta Concentration:  -0.4571451490786567
# Theta Relaxation:  -96.69712520829752
# Mental State: Relaxed
# Delta:  -0.46526521671371046  Theta:  -0.005106456230173307  Alpha:  -0.1301717958208853  Beta:  -0.11121879262038102
# Alpha Relaxation:  -0.026109506393328888
# Beta Concentration:  -0.5110710633774889
# Theta Relaxation:  -35.6715603791775
# Mental State: Relaxed
# Delta:  -0.06211753327899413  Theta:  -0.020265839820652668  Alpha:  -0.314758473058028  Beta:  -0.0046972913052325555
# Alpha Relaxation:  -0.07286683483124153
# Beta Concentration:  -0.5812930962446128
# Theta Relaxation:  -12.902169614816174
# Mental State: Relaxed
# Delta:  0.06104258664316665  Theta:  -0.1960172671784299  Alpha:  -0.31373694850104683  Beta:  -0.0196981330331757
# Alpha Relaxation:  -0.11680112042347673
# Beta Concentration:  -0.6374774903641595
# Theta Relaxation:  -7.6814639837344165
# Mental State: Relaxed
# Delta:  0.2867510465914667  Theta:  -0.30338781117501434  Alpha:  -0.25504903661292144  Beta:  -0.12817303364403632
# Alpha Relaxation:  -0.13350275065311426
# Beta Concentration:  -0.6564927974205373
# Theta Relaxation:  -6.2474110370849365
# Mental State: Relaxed
# Delta:  0.4601584555119872  Theta:  -0.17974533405750687  Alpha:  -0.24504400411027716  Beta:  -0.03600838407756167
# Alpha Relaxation:  -0.11337107036765492
# Beta Concentration:  -0.6713070120853629
# Theta Relaxation:  -6.033427719192564
# Mental State: Relaxed
# Delta:  0.5355204324020062  Theta:  -0.1691929969844279  Alpha:  -0.2898601195274546  Beta:  -0.036097311518406394
# Alpha Relaxation:  -0.13199643016109802
# Beta Concentration:  -0.7165610726210165
# Theta Relaxation:  -4.1962685334329075
# Mental State: Relaxed
# Delta:  0.8211789765857391  Theta:  -0.16052740474795457  Alpha:  -0.2721093037483855  Beta:  -0.09812341794631255
# Alpha Relaxation:  -0.14407191721480742
# Beta Concentration:  -0.7364529258983087
# Theta Relaxation:  -3.219163854821273
# Mental State: Relaxed
# Delta:  0.7810067828809  Theta:  0.1901036892004669  Alpha:  -0.2626700161158746  Beta:  -0.0908831222564941
# Alpha Relaxation:  -0.12976828730167314
# Beta Concentration:  -0.6245953458766718
# Theta Relaxation:  -3.529682950797786
# Mental State: Relaxed
# Delta:  0.5236722615142233  Theta:  0.30359556217971095  Alpha:  -0.15715138718683547  Beta:  -0.11201413197510167
# Alpha Relaxation:  -0.11697283546258272
# Beta Concentration:  -0.5205825629729556
# Theta Relaxation:  -3.985690336661139
# Mental State: Relaxed
# Delta:  0.01923718027180538  Theta:  0.16915483787994112  Alpha:  -0.06813955928245231  Beta:  -0.21734371203423125
# Alpha Relaxation:  -0.09382765374883593
# Beta Concentration:  -0.4972636553586858
# Theta Relaxation:  -5.089342086005029
# Mental State: Relaxed
# Delta:  0.021833694631912186  Theta:  0.07569413054308641  Alpha:  -0.149978050297292  Beta:  -0.20014012400202547
# Alpha Relaxation:  -0.12347497272693032
# Beta Concentration:  -0.5338681162208226
# Theta Relaxation:  -3.8226393636767315
# Mental State: Relaxed
# Delta:  0.0868900332410787  Theta:  -0.016966858560761  Alpha:  -0.2789238960810133  Beta:  -0.17847787323094597
# Alpha Relaxation:  -0.253408996331845
# Beta Concentration:  -0.7655226525655537
# Theta Relaxation:  -1.5774434836539442
# Mental State: Relaxed
# Delta:  -0.1029033553366285  Theta:  -0.215472754926992  Alpha:  -0.46465286727543775  Beta:  -0.18283191321138745
# Alpha Relaxation:  -0.5017737400663228
# Beta Concentration:  -1.60628533595248
# Theta Relaxation:  -0.5163737451599708
# Mental State: Relaxed
# Delta:  -0.23839963078563198  Theta:  -0.4000044172959548  Alpha:  -0.3703942302670395  Beta:  -0.10898920448552228
# Alpha Relaxation:  -0.8366595228601409
# Beta Concentration:  -12.536219108097384
# Theta Relaxation:  -0.053762582215088846
# Mental State: Relaxed
# Delta:  -0.04387988147727136  Theta:  -0.3519311347467521  Alpha:  -0.40379766266820943  Beta:  -0.04011678865488946
# Alpha Relaxation:  -1.1274518372353064
# Beta Concentration:  5.440528538464329
# Theta Relaxation:  0.10616367796350282
# Mental State: Relaxed
# Delta:  0.040417021099180085  Theta:  -0.22683943915198815  Alpha:  -0.2491349641606806  Beta:  0.009830266638300748
# Alpha Relaxation:  -1.3327530652954083
# Beta Concentration:  2.7829453219352844
# Theta Relaxation:  0.19151542435911698
# Mental State: Relaxed
# Delta:  0.24972071260440365  Theta:  -0.02118629619022623  Alpha:  -0.2799600250304922  Beta:  -0.025236269940291812
# Alpha Relaxation:  -1.4409184643256507
# Beta Concentration:  2.2355737716679425
# Theta Relaxation:  0.2188241194243421
# Mental State: Relaxed
# Delta:  0.21456720149815658  Theta:  -0.004295098383737889  Alpha:  -0.2830526643737298  Beta:  -0.12576011095005155
# Alpha Relaxation:  -1.5198874635024868
# Beta Concentration:  1.810671184369487
# Theta Relaxation:  0.24819066093822825
# Mental State: Relaxed
# Delta:  0.15863817083527507  Theta:  -0.17202695375341143  Alpha:  -0.11735643956739288  Beta:  -0.19421134780286403
# Alpha Relaxation:  -1.6127823554618526
# Beta Concentration:  1.3104514851970084
# Theta Relaxation:  0.337875200247538
# Mental State: Relaxed
# Delta:  0.16949170114550177  Theta:  -0.3243778102824572  Alpha:  -0.0817078057565382  Beta:  -0.23588212668351025
# Alpha Relaxation:  -1.5401445826358255
# Beta Concentration:  1.0690092291963453
# Theta Relaxation:  0.42536225897430047
# Mental State: Relaxed
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 124
#     120 eeg_data, timestamp = inlet.pull_chunk(
#     121     timeout=1, max_samples=int(SHIFT_LENGTH * fs))
#     123 # Only keep the channel we're interested in
# --> 124 ch_data = np.array(eeg_data)[:, INDEX_CHANNEL]
#     126 # Update EEG buffer with the new data
#     127 eeg_buffer, filter_state = utils.update_buffer(
#     128     eeg_buffer, ch_data, notch=True,
#     129     filter_state=filter_state)
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
# Disconnected.
# 2024-03-26 11:24:44.283 (2549.299s) [R_Muse          ]      data_receiver.cpp:344    ERR| Stream transmission broke off (Input stream error.); re-connecting...
